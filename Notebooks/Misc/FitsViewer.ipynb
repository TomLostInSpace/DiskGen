# %% [markdown]
# ## Fits file viewer and deprojector

# %%
import numpy as np
import matplotlib.pyplot as plt
import astropy.io.fits as fits

# %%
fit = fits.open("../fits/dm_tau.fits")
fit.info()
img = fit[0].data
print(img.shape)

img2d = np.squeeze(img)
print(img2d.shape)

plt.figure(figsize=(8, 5))
plt.imshow(img2d, origin='lower', cmap='gray')
plt.colorbar()
plt.show()
fit.close()
# Out:
# Filename: ../fits/dm_tau.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     265   (2000, 2000, 1, 1)   float32
# (1, 1, 2000, 2000)
# (2000, 2000)
