# %% [markdown]
# ## Test for profile fit

# %%
import numpy as np
import matplotlib.pyplot as plt
r = np.linspace(0, 127, 182)

# %% [markdown]
# # Taking a look at the simulation images

# %%
# Here goes the npy file with the symulation density profiles
img = np.load("../profiles/dens_test.npy")
for i in range(1):
    # Plot the image
    plt.imshow(img[i], cmap="grey")
    plt.colorbar()
    plt.show()

    # Plot the radial profile
    # Center coordinates
    ny, nx = img[i].shape
    y, x = np.indices((ny, nx))
    center_x = 128
    center_y = 128
    print(center_x, center_y)

    # Radial distance from the center
    r_dist = np.sqrt((x - center_x)**2 + (y - center_y)**2)

    # Convert to integer for binning
    r_int = r_dist.astype(int)

    # Calculate the radial profile
    tbin = np.bincount(r_int.ravel(), img[i].ravel())
    nr = np.bincount(r_int.ravel())
    sim_profile = tbin / np.maximum(nr, 1)
    print(sim_profile.shape)
    print(sim_profile)

    # Plot
    plt.figure(figsize=(8, 5))

    plt.plot(r, sim_profile)
    plt.xlabel("Radius")
    plt.ylabel("Mean intensity")
    plt.title("Radial intensity profile")
    plt.grid(True)
    plt.show()
# Out:
# 128 128
# (182,)
# [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  2.58117644e-04 1.23761675e-03 1.64383424e-03 1.49709391e-03
#  1.50009372e-03 1.51129832e-03 1.47985584e-03 1.43381489e-03
#  1.36166892e-03 1.29497135e-03 1.19369715e-03 1.10290551e-03
#  1.04878191e-03 1.01300192e-03 9.81442445e-04 9.46258645e-04
#  8.96044117e-04 8.24499086e-04 7.21285824e-04 5.85700408e-04
#  4.25321690e-04 2.78043574e-04 1.69186867e-04 1.12727092e-04
#  8.97642444e-05 8.20047400e-05 8.31662505e-05 7.88354786e-05
#  8.29236003e-05 9.90446737e-05 1.38091611e-04 2.12345884e-04
#  3.22112513e-04 4.50193584e-04 5.70395750e-04 6.72892541e-04
#  7.44298535e-04 8.04959742e-04 8.40957452e-04 8.70837947e-04
#  8.87124678e-04 8.97081093e-04 8.96971266e-04 9.00076521e-04
#  8.97138531e-04 8.88238872e-04 8.78289453e-04 8.68636171e-04
#  8.60937283e-04 8.52084774e-04 8.47134316e-04 8.43379768e-04
#  8.40054320e-04 8.36403033e-04 8.30114766e-04 8.23286233e-04
#  8.15630462e-04 8.07247815e-04 8.00534104e-04 7.92601676e-04
#  7.84052292e-04 7.75485914e-04 7.67968528e-04 7.57128144e-04
#  7.44746896e-04 7.34015298e-04 7.22559974e-04 7.13449865e-04
#  7.06748222e-04 7.01142246e-04 6.92172346e-04 6.82294286e-04
#  6.73015644e-04 6.62889551e-04 6.53905971e-04 6.46816572e-04
#  6.40405530e-04 6.32188892e-04 6.22076438e-04 6.12602079e-04
#  6.05905499e-04 6.01244054e-04 5.96556456e-04 5.90727283e-04
#  5.83462646e-04 5.76045256e-04 5.70730886e-04 5.67390848e-04
#  5.63394373e-04 5.56841280e-04 5.49590709e-04 5.43690896e-04
#  5.40102240e-04 5.37089272e-04 5.32592959e-04 5.26856847e-04
#  5.22121404e-04 5.19644726e-04 5.17174443e-04 5.12674640e-04
#  5.07017382e-04 5.02481510e-04 4.99596623e-04 4.96376760e-04
#  4.91838451e-04 4.87782833e-04 4.84614346e-04 4.81624055e-04
#  4.77927782e-04 4.73742984e-04 4.57745013e-04 2.39469982e-04
#  1.84950205e-05 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00]
